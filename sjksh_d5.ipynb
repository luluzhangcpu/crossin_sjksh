# %%
# d5 利用 Pyecharts 将链家房源信息、A 股基本信息根据相应特点制作地图图表
import pandas as pd
import numpy as np

# %%
# 读取CSV格式文件
df1 = pd.read_csv('/Users/apple/Desktop/Task_4_lianjia_sale.csv')
print(df1)
# Out:
#                                 房型     价格                 小区   面积（㎡）  建造年份  \
# 0         大华电梯两房/房型正气/开门南北通/房东诚意出售  76531  大华锦绣华城(十六街区)(公寓)    90.16  2010
# 1      非底楼 满五年唯一 税费少 婚房装修 楼称佳 户型方正  52290               芳雅苑    63.11  1995
# 2      满五唯一+7号线锦绣路+复式房+带阁楼+小区央位+精装  62878               锦博苑    79.52  2007
# 3         13号线陈春路地铁400米中间楼层诚意卖看房方便  45866              鹏海小区    71.95  1997
# 4        朝阳正气一房，采光好，坐看花园，户型方正，看房方便  83942            万邦都市花园    54.80  2004
# ...                            ...    ...                ...     ...   ...
# 66010                富丽苑 2室2厅 275万  29743               富丽苑    92.46  2005
# 66011      房东自住精装修，集中式空调系统加地暖，带电梯。  35650            金辉兰湖美域   182.33  2013
# 66012             美兰湖颐景园 2室2厅 276万  32838            美兰湖颐景园    84.05  2007
# 66013     五楼低总价，两房朝南，满五唯一，格局好，配套齐全  26493              罗南二村    69.83  1996
# 66014      满五唯一，带电梯，精装修近地铁，户型方正楼层好  39983             美兰湖岭域    92.04  2010
#
#           户型     朝向  装修类型           楼层  区域
# 0      2室2厅      南    简装    中楼层(共18层)   浦东
# 1      2室1厅      南    精装     低楼层(共6层)   浦东
# 2      2室2厅      南    精装     高楼层(共6层)   浦东
# 3      2室1厅      南    简装     中楼层(共6层)   浦东
# 4      1室1厅      南    简装    中楼层(共11层)   浦东
# ...      ...    ...   ...          ...  ..
# 66010  2室2厅      南    精装     中楼层(共6层)   宝山
# 66011  4室2厅    南 北    精装     高楼层(共5层)   宝山
# 66012  2室2厅      南    精装     低楼层(共5层)   宝山
# 66013  2室1厅      南    简装     高楼层(共6层)   宝山
# 66014  2室2厅      南    精装     中楼层(共6层)   宝山
#
# [66015 rows x 10 columns]

# %%
# task1--根据之前所统计的上海各个区的房均价数据，
# 利用Pyecharts中的Map，以上海地图为背景作可视化展示图
# 利用groupby函数，以【区域】字段进行groupby，
# 同时结合agg聚合函数统计各个区域平均房价，将统计所得平均房价命名为【区域平均价格】
# df.groupby("被统计的列")["选择一列做运算"].agg({"新列名": "mean"}).sort_values(by="新列名")
df_avg = df1.groupby("区域")["价格"].agg(区域平均价格='mean').sort_values(by='区域平均价格')
print(df_avg.head(5))
# Out:
#           区域平均价格
# 区域
# 金山  19304.818824
# 奉贤  23662.131268
# 松江  36461.715479
# 嘉定  36587.687199
# 青浦  37078.860149

# %%
# 导入pyecharts.charts中的Bar，作条形图
from pyecharts.charts import Map
# 导入配置项入口
from pyecharts import options as opts

# %%
# 定义区域名字
districts = ['金山区', '奉贤区', '嘉定区','松江区', '青浦区', '宝山区',\
             '闵行区', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区']
# 将avg_price数据值转成list 并将数值转成整数，作为纵坐标数据
avg_price = np.round(df_avg["区域平均价格"].values).tolist()

# %%
# 构造地图对象
m = Map()
m.add("房价", [list(z) for z in zip(districts, avg_price)], "上海")
# 设置标题，设置数值范围0-10万，is_piecewise标签值连续
m.set_global_opts(title_opts=opts.TitleOpts(title="上海各区房价"),\
                  visualmap_opts=opts.VisualMapOpts(max_=100000, is_piecewise=False),)

# %%
# 直接在jupytr notebook中渲染
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="b0c638ab00b9442e9e5c31ce2d1935ee" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_b0c638ab00b9442e9e5c31ce2d1935ee = echarts.init(
#                     document.getElementById('b0c638ab00b9442e9e5c31ce2d1935ee'), 'white', {renderer: 'canvas'});
#                 var option_b0c638ab00b9442e9e5c31ce2d1935ee = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u623f\u4ef7",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u4e0a\u6d77",
#             "data": [
#                 {
#                     "name": "\u91d1\u5c71\u533a",
#                     "value": 19305.0
#                 },
#                 {
#                     "name": "\u5949\u8d24\u533a",
#                     "value": 23662.0
#                 },
#                 {
#                     "name": "\u5609\u5b9a\u533a",
#                     "value": 36462.0
#                 },
#                 {
#                     "name": "\u677e\u6c5f\u533a",
#                     "value": 36588.0
#                 },
#                 {
#                     "name": "\u9752\u6d66\u533a",
#                     "value": 37079.0
#                 },
#                 {
#                     "name": "\u5b9d\u5c71\u533a",
#                     "value": 42578.0
#                 },
#                 {
#                     "name": "\u95f5\u884c\u533a",
#                     "value": 49081.0
#                 },
#                 {
#                     "name": "\u6d66\u4e1c\u65b0\u533a",
#                     "value": 55413.0
#                 },
#                 {
#                     "name": "\u666e\u9640\u533a",
#                     "value": 57943.0
#                 },
#                 {
#                     "name": "\u6768\u6d66\u533a",
#                     "value": 62727.0
#                 },
#                 {
#                     "name": "\u8679\u53e3\u533a",
#                     "value": 66165.0
#                 },
#                 {
#                     "name": "\u957f\u5b81\u533a",
#                     "value": 72100.0
#                 },
#                 {
#                     "name": "\u9759\u5b89\u533a",
#                     "value": 74305.0
#                 },
#                 {
#                     "name": "\u5f90\u6c47\u533a",
#                     "value": 75396.0
#                 },
#                 {
#                     "name": "\u9ec4\u6d66\u533a",
#                     "value": 95015.0
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u623f\u4ef7"
#             ],
#             "selected": {
#                 "\u623f\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5404\u533a\u623f\u4ef7",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_b0c638ab00b9442e9e5c31ce2d1935ee.setOption(option_b0c638ab00b9442e9e5c31ce2d1935ee);
#         });
#     </script>

# %%
# task2--导入tushare数据包，提取A股基本数据信息，
# 利用groupby函数统计每个省份的公司数量，并以中国地图为背景作相应图表
# 导入tushare包，需要pip安装
import tushare as ts
# 获取股票基本数据
pro = ts.pro_api()
df2 = pro.stock_basic()
# 展示前10行数据
print(df2.head(10))
# Out:
#      ts_code  symbol   name area industry market list_date
# 0  000001.SZ  000001   平安银行   深圳       银行     主板  19910403
# 1  000002.SZ  000002    万科A   深圳     全国地产     主板  19910129
# 2  000004.SZ  000004   国华网安   深圳     软件服务     主板  19910114
# 3  000005.SZ  000005   ST星源   深圳     环境保护     主板  19901210
# 4  000006.SZ  000006   深振业A   深圳     区域地产     主板  19920427
# 5  000007.SZ  000007  *ST全新   深圳     酒店餐饮     主板  19920413
# 6  000008.SZ  000008   神州高铁   北京     运输设备     主板  19920507
# 7  000009.SZ  000009   中国宝安   深圳     电气设备     主板  19910625
# 8  000010.SZ  000010   美丽生态   深圳     建筑工程     主板  19951027
# 9  000011.SZ  000011   深物业A   深圳     区域地产     主板  19920330

# %%
# 利用groupby函数，以【area】字段进行groupby，
# 同时结合agg聚合函数统计各个area公司数量，将统计所得数据命名为【公司数量】
# df.groupby("被统计的列")["选择一列做运算"].agg({"新列名": "count"})
df_num = df2.groupby("area")["name"].agg(公司数量=("count"))
print(df_num)
# Out:
#       公司数量
# area
# 上海     388
# 云南      40
# 内蒙      26
# 北京     417
# 吉林      47
# 四川     155
# 天津      63
# 宁夏      15
# 安徽     145
# 山东     264
# 山西      40
# 广东     390
# 广西      38
# 新疆      58
# 江苏     569
# 江西      67
# 河北      66
# 河南      96
# 浙江     609
# 海南      34
# 深圳     371
# 湖北     126
# 湖南     130
# 甘肃      35
# 福建     162
# 西藏      21
# 贵州      33
# 辽宁      78
# 重庆      60
# 陕西      65
# 青海      11
# 黑龙江     38

# %%
# 导入pyecharts.charts中的 Bar 作地图
from pyecharts.charts import Map
# 导入配置项入口
from pyecharts import options as opts

# %%
# 将df_num的索引即【area】提取出来，并转换成list
df_province = df_num.index.values.tolist()
# 将df_num的【公司数量】一列的数据值提取出来，并转换成list
df_company_num = df_num["公司数量"].values.tolist()

# %%
# 构造地图对象
m = Map()
# 中国地图
m.add("商家A", [list(z) for z in zip(df_province, df_company_num)], "china")
# 设置标题、设置数值范围0-500，is_piecewise标签值连续或者分段
m.set_global_opts(title_opts=opts.TitleOpts(title="公司地区分布图"),\
                  visualmap_opts=opts.VisualMapOpts(max_=500, is_piecewise=True),)

# 直接在jupytr notebook中渲染
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="86eb0d04545f4834ac706bdff7a1465a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_86eb0d04545f4834ac706bdff7a1465a = echarts.init(
#                     document.getElementById('86eb0d04545f4834ac706bdff7a1465a'), 'white', {renderer: 'canvas'});
#                 var option_86eb0d04545f4834ac706bdff7a1465a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 388
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u5185\u8499",
#                     "value": 26
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 417
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 155
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 63
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 145
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 264
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 390
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 58
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 569
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 96
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 609
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 371
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 162
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 38
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u516c\u53f8\u5730\u533a\u5206\u5e03\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 500,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_86eb0d04545f4834ac706bdff7a1465a.setOption(option_86eb0d04545f4834ac706bdff7a1465a);
#         });
#     </script>

# %%
from pyecharts.charts import Map,Geo
from pyecharts import options as opts
#将数据处理成列表
locate = ['北京','天津','河北','山西','内蒙古','辽宁','吉林','黑龙江','上海','江苏','浙江','安徽','福建','江西','山东','河南','湖北','湖南','广东','广西','海南','重庆','四川','贵州','云南','陕西','甘肃','青海','宁夏','新疆','西藏']
app_price = [10.84,8.65,18.06,8.90,5.04,29.20,8.98,17.80,27.81,24.24,12.72,11.10,6.30,7.00,22.45,16.92,11.00,14.99,18.85,5.85,1.40,7.32,14.61,4.62,6.05,8.07,6.73,15.54,13.00,39.07,25.61,21.3]
list1 = [[locate[i],app_price[i]] for i in range(len(locate))]
map_1 = Map()
map_1.set_global_opts(
    title_opts=opts.TitleOpts(title="2019年全国各省苹果价格表"),
    visualmap_opts=opts.VisualMapOpts(max_=50)  #最大数据范围
    )
map_1.add("2019年全国各省苹果价格", list1, maptype="china")
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="c5268b335bdf4f189145cbfa58f8b6f1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c5268b335bdf4f189145cbfa58f8b6f1 = echarts.init(
#                     document.getElementById('c5268b335bdf4f189145cbfa58f8b6f1'), 'white', {renderer: 'canvas'});
#                 var option_c5268b335bdf4f189145cbfa58f8b6f1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "2019\u5e74\u5168\u56fd\u5404\u7701\u82f9\u679c\u4ef7\u683c",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 10.84
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 8.65
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 18.06
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 8.9
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 5.04
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 29.2
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 8.98
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17.8
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 27.81
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 24.24
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 12.72
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 11.1
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 6.3
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 7.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 22.45
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 16.92
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 11.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 14.99
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 18.85
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 5.85
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 1.4
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 7.32
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 14.61
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 4.62
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 6.05
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 8.07
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 6.73
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 15.54
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 13.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 39.07
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 25.61
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2019\u5e74\u5168\u56fd\u5404\u7701\u82f9\u679c\u4ef7\u683c"
#             ],
#             "selected": {
#                 "2019\u5e74\u5168\u56fd\u5404\u7701\u82f9\u679c\u4ef7\u683c": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "2019\u5e74\u5168\u56fd\u5404\u7701\u82f9\u679c\u4ef7\u683c\u8868",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 50,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_c5268b335bdf4f189145cbfa58f8b6f1.setOption(option_c5268b335bdf4f189145cbfa58f8b6f1);
#         });
#     </script>
